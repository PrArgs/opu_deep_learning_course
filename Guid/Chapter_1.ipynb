# %%
import torch
import numpy as np

# %%
tens = torch.rand(100,2,2)

# %%
#A
#
eigenvalues = torch.linalg.eigvals(tens)
# print(eigenvalues)

#B
# Calculate the Frobenius norm of the 100X2X2 tensor
Frobenius_norm = torch.linalg.matrix_norm(tens)
